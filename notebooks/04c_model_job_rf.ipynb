# %%
DF_PATH = "../data/processed/4_balanced_data.pkl"

ROLE_COLS      = ['DevType']
TECH_COLS      = ['LanguageHaveWorkedWith',
                  'DatabaseHaveWorkedWith',
                  'PlatformHaveWorkedWith',
                  'WebframeHaveWorkedWith',
                  'MiscTechHaveWorkedWith',
                  'ToolsTechHaveWorkedWith',
                  'NEWCollabToolsHaveWorkedWith']

MLFLOW_TRACKING_URI = '../models/mlruns'
MLFLOW_EXPERIMENT_NAME = "skills_jobs_stackoverflow"

LOG_PATH = "../models/temp/"
LOG_DATA_PKL = "data.pkl"
LOG_MODEL_PKL = "model.pkl"
LOG_METRICS_PKL = "metrics.pkl"

# %%
import pandas as pd
import numpy as np
import os
import pickle

import mlflow
from mlflow.tracking import MlflowClient

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import RobustScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

from sklearn.ensemble import RandomForestClassifier

pd.options.display.max_columns=100

# %% [markdown]
# ___
# # Functions

# %%
def calculate_quality(ground_truth, predictoins, metric_function, sort_values=False):
    """
    Calculate the quality of your model according to metric score
    instead of giving a summary of overall quality
    Input:
        ground_truth: from real data
        predictions: the predicted from the model
        metric_function: the metric score function used to measure performance
    Output:
        a dict of all scores w.r.t every class (column) separately
    """
    quality_scores = {}
    for col in predictions.columns:
        role_truth = ground_truth[col].copy()
        role_pred = predictions[col].copy()
        quality_scores[col] = round(metric_function(role_truth, role_pred) * 100, 2)
    
    quality_scores = pd.Series(quality_scores.values(), index=quality_scores.keys())
    if sort_values:
        quality_scores = quality_scores.sort_values()
    
    return quality_scores

# %% [markdown]
# ___
# # Prepare Data:
# ## Read data:

# %%
# Read data
df = pd.read_pickle(DF_PATH)

# %% [markdown]
# ## Split Data to train and test:

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop(['DevType'], axis=1),
                                                    df['DevType'],
                                                    random_state=0)
# Out:
# C:\Users\ahmed\anaconda3\lib\site-packages\pandas\core\generic.py:4150: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)

# %% [markdown]
# ---
# # Train models
# ## Intialize MLflow

# %%
#Initialize client and experiment
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)
client = MlflowClient()

# %%
#Check if experiment already exists; if not create one
try:
    mlflow.create_experiment(MLFLOW_EXPERIMENT_NAME)
except:
    print(f'Experiment "{MLFLOW_EXPERIMENT_NAME}" exists at "{mlflow.get_tracking_uri()}"')
# Out:
# Experiment "skills_jobs_stackoverflow" exists at "../models/mlruns"

# %%
exp = client.get_experiment_by_name(MLFLOW_EXPERIMENT_NAME)
#print(mlflow.get_experiment_by_name(MLFLOW_EXPERIMENT_NAME))
print(exp)
# Out:
# <Experiment: artifact_location='../models/mlruns/0', experiment_id='0', lifecycle_stage='active', name='skills_jobs_stackoverflow', tags={}>

# %% [markdown]
# ## 1. Vanilla Forest

# %%
rf_clf = make_pipeline(RobustScaler(),
                       PCA(n_components=0.95),
                       RandomForestClassifier(n_jobs=8,
                                              verbose=1,
                                              random_state=0))

rf_clf.fit(X_train.values, y_train.values)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    9.9s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:   22.1s finished
# Pipeline(steps=[('robustscaler', RobustScaler()),
#                 ('pca', PCA(n_components=0.95)),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(n_jobs=8, random_state=0, verbose=1))])

# %%
# Evaluate on training set
predictions = pd.DataFrame(rf_clf.predict(X_train.values),
                           columns = y_train.columns)

train_scores = {score.__name__: calculate_quality(y_train, predictions, score)
                for score in [accuracy_score, precision_score, recall_score, f1_score]}
train_scores = pd.concat(train_scores, axis=1)
mean_train_score = train_scores.mean()
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    3.1s finished

# %%
print(mean_train_score)
train_scores
# Out:
# accuracy_score     99.958125
# precision_score    99.873750
# recall_score       99.765625
# f1_score           99.818750
# dtype: float64
#                                                accuracy_score  \
# Academic researcher                                     99.91
# Data or business analyst                                99.97
# Data scientist or machine learning specialist           99.94
# Database administrator                                  99.97
# DevOps specialist                                       99.98
# Developer, QA or test                                   99.97
# Developer, back-end                                     99.93
# Developer, desktop or enterprise applications           99.95
# Developer, embedded applications or devices             99.96
# Developer, front-end                                    99.99
# Developer, full-stack                                   99.98
# Developer, game or graphics                             99.96
# Developer, mobile                                       99.98
# Engineer, data                                          99.96
# Scientist                                               99.91
# System administrator                                    99.97
#
#                                                precision_score  recall_score  \
# Academic researcher                                      99.53         99.72
# Data or business analyst                                 99.84         99.89
# Data scientist or machine learning specialist            99.79         99.79
# Database administrator                                   99.75         99.94
# DevOps specialist                                       100.00         99.80
# Developer, QA or test                                   100.00         99.64
# Developer, back-end                                      99.94         99.81
# Developer, desktop or enterprise applications            99.76         99.88
# Developer, embedded applications or devices             100.00         99.52
# Developer, front-end                                    100.00         99.92
# Developer, full-stack                                    99.98         99.96
# Developer, game or graphics                              99.93         99.56
# Developer, mobile                                        99.95         99.90
# Engineer, data                                          100.00         99.59
# Scientist                                                99.66         99.43
# System administrator                                     99.85         99.90
#
#                                                f1_score
# Academic researcher                               99.62
# Data or business analyst                          99.86
# Data scientist or machine learning specialist     99.79
# Database administrator                            99.85
# DevOps specialist                                 99.90
# Developer, QA or test                             99.82
# Developer, back-end                               99.88
# Developer, desktop or enterprise applications     99.82
# Developer, embedded applications or devices       99.76
# Developer, front-end                              99.96
# Developer, full-stack                             99.97
# Developer, game or graphics                       99.74
# Developer, mobile                                 99.93
# Engineer, data                                    99.79
# Scientist                                         99.54
# System administrator                              99.87

# %%
# Evaluate on test set
predictions = pd.DataFrame(rf_clf.predict(X_test.values), 
                                       columns=y_test.columns)

test_scores = {score.__name__: calculate_quality(y_test, predictions, score)
               for score in [accuracy_score, precision_score, recall_score, f1_score]}
test_scores = pd.concat(test_scores, axis=1)
mean_test_scores = test_scores.mean()
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    1.2s finished

# %%
print(mean_test_scores)
test_scores
# Out:
# accuracy_score     93.666250
# precision_score    95.541250
# recall_score       57.588125
# f1_score           70.990625
# dtype: float64
#                                                accuracy_score  \
# Academic researcher                                     95.27
# Data or business analyst                                94.65
# Data scientist or machine learning specialist           95.80
# Database administrator                                  97.07
# DevOps specialist                                       93.75
# Developer, QA or test                                   97.63
# Developer, back-end                                     82.30
# Developer, desktop or enterprise applications           91.22
# Developer, embedded applications or devices             94.68
# Developer, front-end                                    91.58
# Developer, full-stack                                   84.83
# Developer, game or graphics                             98.27
# Developer, mobile                                       94.53
# Engineer, data                                          94.55
# Scientist                                               98.05
# System administrator                                    94.48
#
#                                                precision_score  recall_score  \
# Academic researcher                                      96.57         64.21
# Data or business analyst                                 97.36         51.55
# Data scientist or machine learning specialist            93.65         71.75
# Database administrator                                   99.49         69.20
# DevOps specialist                                        97.23         46.33
# Developer, QA or test                                    99.70         70.00
# Developer, back-end                                      88.66         47.46
# Developer, desktop or enterprise applications            96.78         41.21
# Developer, embedded applications or devices              95.11         45.26
# Developer, front-end                                     92.51         40.12
# Developer, full-stack                                    80.16         62.78
# Developer, game or graphics                              98.29         77.88
# Developer, mobile                                        96.80         51.23
# Engineer, data                                          100.00         48.75
# Scientist                                                97.54         83.23
# System administrator                                     98.81         50.45
#
#                                                f1_score
# Academic researcher                               77.13
# Data or business analyst                          67.41
# Data scientist or machine learning specialist     81.25
# Database administrator                            81.63
# DevOps specialist                                 62.76
# Developer, QA or test                             82.25
# Developer, back-end                               61.83
# Developer, desktop or enterprise applications     57.81
# Developer, embedded applications or devices       61.33
# Developer, front-end                              55.97
# Developer, full-stack                             70.42
# Developer, game or graphics                       86.90
# Developer, mobile                                 67.00
# Engineer, data                                    65.54
# Scientist                                         89.82
# System administrator                              66.80

# %% [markdown]
# ## Prepare Logs

# %%
# Data details
data_details = {"data_path": DF_PATH,
                "training_indices": X_train.index.tolist(),
                "test_indices": X_test.index.tolist(),
                "features_names": X_train.columns.droplevel(0).tolist(),
                "targets_names": y_train.columns.tolist()}

with open(os.path.join(LOG_PATH, LOG_DATA_PKL), 'wb') as output_file:
    pickle.dump(data_details, output_file)

# %%
# Model
model = {"model_description": "Random Forest: with PCA - Basic",
         "model_details": str(rf_clf),
         "model_object": rf_clf}

with open(os.path.join(LOG_PATH, LOG_MODEL_PKL), 'wb') as output_file:
    pickle.dump(model, output_file)

# %%
# Performance details
classes_metrics = {"train_scores": train_scores,
                   "test_scores": test_scores}

with open(os.path.join(LOG_PATH, LOG_METRICS_PKL), 'wb') as output_file:
    pickle.dump(classes_metrics, output_file)

# %% [markdown]
# ## Logging

# %%
# Start a new run and track
with mlflow.start_run(experiment_id=exp.experiment_id,
                      run_name=model['model_description']):
    #Log pickles
    mlflow.log_artifacts(LOG_PATH)
    
    #Track metrics
    for metric, score in mean_test_scores.items():
        mlflow.log_metric(metric, score)

# %% [markdown]
# ___
# # Hyper parameter tuning:
# **Here we use grid search to tune our parameters**

# %%
hpt_rf_clf = make_pipeline(RobustScaler(),
                           PCA(),
                           RandomForestClassifier(n_jobs=8,
                                                  verbose=1,
                                                  random_state=0))

# %%
# Get all the model patameter to specify which to tune
list(hpt_rf_clf.get_params().keys())
# Out:
# ['memory',
#  'steps',
#  'verbose',
#  'robustscaler',
#  'pca',
#  'randomforestclassifier',
#  'robustscaler__copy',
#  'robustscaler__quantile_range',
#  'robustscaler__unit_variance',
#  'robustscaler__with_centering',
#  'robustscaler__with_scaling',
#  'pca__copy',
#  'pca__iterated_power',
#  'pca__n_components',
#  'pca__random_state',
#  'pca__svd_solver',
#  'pca__tol',
#  'pca__whiten',
#  'randomforestclassifier__bootstrap',
#  'randomforestclassifier__ccp_alpha',
#  'randomforestclassifier__class_weight',
#  'randomforestclassifier__criterion',
#  'randomforestclassifier__max_depth',
#  'randomforestclassifier__max_features',
#  'randomforestclassifier__max_leaf_nodes',
#  'randomforestclassifier__max_samples',
#  'randomforestclassifier__min_impurity_decrease',
#  'randomforestclassifier__min_samples_leaf',
#  'randomforestclassifier__min_samples_split',
#  'randomforestclassifier__min_weight_fraction_leaf',
#  'randomforestclassifier__n_estimators',
#  'randomforestclassifier__n_jobs',
#  'randomforestclassifier__oob_score',
#  'randomforestclassifier__random_state',
#  'randomforestclassifier__verbose',
#  'randomforestclassifier__warm_start']

# %%
# Write down the values to tune on
tuned_parameters = [{
    'pca__n_components': [0.7, 0.85, 0.95],
    'randomforestclassifier__n_estimators': [250, 500],
    'randomforestclassifier__max_depth': [3, 10, None],
}]

# %%
hpt_rf_clf = GridSearchCV(hpt_rf_clf, tuned_parameters)
hpt_rf_clf.fit(X_train.values, y_train.values)
# Out:
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    8.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   13.6s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   16.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.9s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    7.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    7.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.5s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    6.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.3s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    7.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.5s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   11.9s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   13.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    2.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:   12.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   15.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    2.6s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:    9.8s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   13.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    2.6s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   11.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    2.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   12.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   14.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.1s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   14.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   18.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.6s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    9.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   13.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   13.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   21.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   17.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   22.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   16.8s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   21.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.6s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   15.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   32.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   38.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.6s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   11.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   27.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   30.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.3s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   12.9s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   32.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   36.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.3s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   26.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   29.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.2s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   12.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   29.9s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   35.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   20.8s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   28.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   17.7s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   24.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   25.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   32.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   17.8s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   23.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.5s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   20.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   28.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.1s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   21.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   49.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   57.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    2.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   18.6s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   42.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   48.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    4.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   20.6s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   49.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   56.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    4.0s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   19.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   44.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   50.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.6s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    6.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   22.6s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   52.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:  1.0min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    4.0s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    6.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   10.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   10.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   12.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    8.6s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   10.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    8.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   10.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.0s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   10.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.3s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.9s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   16.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   19.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    4.1s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    9.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   17.9s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   19.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.2s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   19.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   21.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.2s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   18.9s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   21.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.2s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    9.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   19.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   22.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    6.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   16.6s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   22.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.2s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   14.6s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   20.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.0s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   19.9s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   24.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   17.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   22.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   19.9s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   24.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.5s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   15.9s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   40.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   46.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.6s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   19.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   44.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   49.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.2s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   18.8s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   44.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   49.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    4.9s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   18.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   44.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   50.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    4.2s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   19.8s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed: 146.2min
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed: 146.4min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    7.3s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   36.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   50.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   38.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   56.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.6s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    8.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   38.9s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   51.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.3s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   38.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   51.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.5s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   40.7s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   50.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.0s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   33.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:  1.5min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    4.5s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   35.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:  1.6min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    4.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   32.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:  1.5min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    5.0s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   30.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:  1.4min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    6.0s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   39.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:  1.7min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    4.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   10.8s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   15.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.5s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   11.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   15.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    3.2s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   12.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   15.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   12.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   16.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   10.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   13.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   11.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   25.9s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   31.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    9.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   21.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   24.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    9.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   23.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   26.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    6.0s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   10.6s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   26.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   30.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    4.0s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   10.7s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   23.9s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   27.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    5.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   25.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   32.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.9s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   32.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   42.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.0s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   21.6s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   29.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.6s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   24.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   32.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   23.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   31.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   23.9s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   54.8s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:  1.1min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    5.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   22.9s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   53.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:  1.0min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    4.6s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   24.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   57.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:  1.1min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.3s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   21.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   54.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:  1.0min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.2s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    5.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   24.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   57.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:  1.1min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   40.7s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   55.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.3s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   42.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   53.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.0s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   33.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   43.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   32.6s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   45.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.2s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   36.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   47.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   30.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:  1.3min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   37.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:  1.5min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.6s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    7.6s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   39.6s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:  1.7min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    4.1s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   34.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:  1.5min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    2.9s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   29.9s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:  1.4min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    4.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   27.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   35.1s finished
# GridSearchCV(estimator=Pipeline(steps=[('robustscaler', RobustScaler()),
#                                        ('pca', PCA()),
#                                        ('randomforestclassifier',
#                                         RandomForestClassifier(n_jobs=8,
#                                                                random_state=0,
#                                                                verbose=1))]),
#              param_grid=[{'pca__n_components': [0.7, 0.85, 0.95],
#                           'randomforestclassifier__max_depth': [3, 10, None],
#                           'randomforestclassifier__n_estimators': [250, 500]}])

# %%
# Print the tuned model parameters
hpt_rf_clf.best_params_
# Out:
# {'pca__n_components': 0.7,
#  'randomforestclassifier__max_depth': None,
#  'randomforestclassifier__n_estimators': 250}

# %% [markdown]
# ## Evaluate the model

# %%
# Evaluate on training set
predictions = pd.DataFrame(hpt_rf_clf.predict(X_train.values),
                           columns = y_train.columns)

train_scores = {score.__name__: calculate_quality(y_train, predictions, score)
                for score in [accuracy_score, precision_score, recall_score, f1_score]}
train_scores = pd.concat(train_scores, axis=1)
mean_train_scores = train_scores.mean()
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    7.4s finished

# %%
print(mean_train_scores)
train_scores
# Out:
# accuracy_score     99.960000
# precision_score    99.858125
# recall_score       99.798750
# f1_score           99.827500
# dtype: float64
#                                                accuracy_score  \
# Academic researcher                                     99.91
# Data or business analyst                                99.97
# Data scientist or machine learning specialist           99.94
# Database administrator                                  99.97
# DevOps specialist                                       99.98
# Developer, QA or test                                   99.97
# Developer, back-end                                     99.93
# Developer, desktop or enterprise applications           99.95
# Developer, embedded applications or devices             99.96
# Developer, front-end                                    99.99
# Developer, full-stack                                   99.98
# Developer, game or graphics                             99.97
# Developer, mobile                                       99.99
# Engineer, data                                          99.97
# Scientist                                               99.91
# System administrator                                    99.97
#
#                                                precision_score  recall_score  \
# Academic researcher                                      99.53         99.72
# Data or business analyst                                 99.89         99.84
# Data scientist or machine learning specialist            99.79         99.79
# Database administrator                                   99.69        100.00
# DevOps specialist                                       100.00         99.80
# Developer, QA or test                                    99.86         99.79
# Developer, back-end                                      99.96         99.79
# Developer, desktop or enterprise applications            99.88         99.76
# Developer, embedded applications or devices              99.88         99.70
# Developer, front-end                                    100.00         99.92
# Developer, full-stack                                    99.98         99.96
# Developer, game or graphics                              99.93         99.63
# Developer, mobile                                        99.95         99.95
# Engineer, data                                          100.00         99.69
# Scientist                                                99.54         99.54
# System administrator                                     99.85         99.90
#
#                                                f1_score
# Academic researcher                               99.62
# Data or business analyst                          99.86
# Data scientist or machine learning specialist     99.79
# Database administrator                            99.85
# DevOps specialist                                 99.90
# Developer, QA or test                             99.82
# Developer, back-end                               99.88
# Developer, desktop or enterprise applications     99.82
# Developer, embedded applications or devices       99.79
# Developer, front-end                              99.96
# Developer, full-stack                             99.97
# Developer, game or graphics                       99.78
# Developer, mobile                                 99.95
# Engineer, data                                    99.84
# Scientist                                         99.54
# System administrator                              99.87

# %%
# Evaluate on test set
predictions = pd.DataFrame(hpt_rf_clf.predict(X_test.values), 
                                       columns=y_test.columns)

test_scores = {score.__name__: calculate_quality(y_test, predictions, score)
               for score in [accuracy_score, precision_score, recall_score, f1_score]}
test_scores = pd.concat(test_scores, axis=1)
mean_test_scores = test_scores.mean()
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    2.7s finished

# %%
print(mean_test_scores)
test_scores
# Out:
# accuracy_score     93.77375
# precision_score    92.35625
# recall_score       60.59625
# f1_score           72.47500
# dtype: float64
#                                                accuracy_score  \
# Academic researcher                                     95.40
# Data or business analyst                                94.67
# Data scientist or machine learning specialist           95.82
# Database administrator                                  97.02
# DevOps specialist                                       94.02
# Developer, QA or test                                   97.62
# Developer, back-end                                     82.37
# Developer, desktop or enterprise applications           91.15
# Developer, embedded applications or devices             94.90
# Developer, front-end                                    91.45
# Developer, full-stack                                   85.75
# Developer, game or graphics                             98.32
# Developer, mobile                                       94.62
# Engineer, data                                          94.77
# Scientist                                               97.98
# System administrator                                    94.52
#
#                                                precision_score  recall_score  \
# Academic researcher                                      94.34         67.02
# Data or business analyst                                 93.32         54.19
# Data scientist or machine learning specialist            89.72         75.69
# Database administrator                                   98.74         69.20
# DevOps specialist                                        91.30         52.35
# Developer, QA or test                                    99.40         70.00
# Developer, back-end                                      82.39         52.92
# Developer, desktop or enterprise applications            94.12         42.01
# Developer, embedded applications or devices              92.03         49.55
# Developer, front-end                                     82.10         45.88
# Developer, full-stack                                    78.06         70.14
# Developer, game or graphics                              97.77         79.01
# Developer, mobile                                        95.29         52.92
# Engineer, data                                           96.55         52.66
# Scientist                                                95.95         84.03
# System administrator                                     96.62         51.97
#
#                                                f1_score
# Academic researcher                               78.37
# Data or business analyst                          68.57
# Data scientist or machine learning specialist     82.11
# Database administrator                            81.37
# DevOps specialist                                 66.54
# Developer, QA or test                             82.15
# Developer, back-end                               64.45
# Developer, desktop or enterprise applications     58.09
# Developer, embedded applications or devices       64.42
# Developer, front-end                              58.86
# Developer, full-stack                             73.89
# Developer, game or graphics                       87.39
# Developer, mobile                                 68.05
# Engineer, data                                    68.15
# Scientist                                         89.60
# System administrator                              67.59

# %% [markdown]
# ## Prepare logs:

# %%
# Data details
data_details = {"data_path": DF_PATH,
                "training_indices": X_train.index.tolist(),
                "test_indices":     X_test.index.tolist(), 
                "features_names":   X_train.columns.droplevel(0).tolist(),
                "targets_names":    y_train.columns.tolist()}

with open(os.path.join(LOG_PATH, LOG_DATA_PKL), "wb") as output_file:
    pickle.dump(data_details, output_file)

# %%
# Model
model = {"model_description": "Random Forest: with PCA + Hyperparamter tuning",
         "model_details": str(hpt_rf_clf),
         "model_object": hpt_rf_clf} 

with open(os.path.join(LOG_PATH, LOG_MODEL_PKL), "wb") as output_file:
    pickle.dump(model, output_file)

# %%
# Preformance details
classes_metrics = {"train_scores": train_scores, 
                   "test_scores":  test_scores}

with open(os.path.join(LOG_PATH, LOG_METRICS_PKL), "wb") as output_file:
    pickle.dump(classes_metrics, output_file)

# %% [markdown]
# ## Logginig:

# %%
# Start a new run and track 
with mlflow.start_run(experiment_id=exp.experiment_id, 
                      run_name=model["model_description"]):
    # Log pickles
    mlflow.log_artifacts(LOG_PATH)  
    
    # Track metrics 
    for metric, score in mean_test_scores.items():
        mlflow.log_metric(metric, score)
